# %% [markdown]
# # 03 - Statistical Arbitrage Overlay
#
# Inspect discovered pairs and the top pair spread plot.

# %%
from pathlib import Path
import pandas as pd
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
pairs_path = PROJECT_ROOT / 'outputs' / 'pairs.csv'
if pairs_path.exists():
    display(pd.read_csv(pairs_path))
else:
    print('Run the pipeline first.')
