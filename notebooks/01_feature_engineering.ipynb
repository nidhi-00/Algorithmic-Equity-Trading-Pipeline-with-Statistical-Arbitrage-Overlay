# %% [markdown]
# # 01 - Feature Engineering and Cleaning
#
# Run this notebook after placing `daily_prices.csv` in `data/` or use the synthetic dataset.

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / 'src'))
from precog_trading.synthetic import generate_synthetic_prices
from precog_trading.io import load_prices_csv
from precog_trading.cleaning import clean_prices
from precog_trading.features import engineer_features

path = PROJECT_ROOT / 'data' / 'sample_daily_prices.csv'
generate_synthetic_prices(path)
df = load_prices_csv(path)
cleaned = clean_prices(df)
feat = engineer_features(cleaned.data)
cleaned.report, feat.head()
